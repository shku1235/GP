# 111140  C0276653  MI2013-809798.006;poljradiol-81-382-g001;mjhid...
# 111141  C3504297                    JCIS-3-64-g008;IJOEM-17-25-g004
# 111142  C0919932  cmj-47-173-g001;JCIS-4-14-g002;JCIS-4-14-g004;...
# 111143  C0108677                           oncotarget-07-2508-g004a
# 111144  C2077862                                  jkms-31-1143-g002
# 111145  C0077918                                    1472-6750-5-9-2
# 111146  C0400207  acfs-15-32-g005;1532-429X-15-54-11;1532-429X-1...
# 111147  C0854824  IJABMR-4-50-g002;1742-6413-3-24-8;JSC2013-7528...
# 111148  C4069439  40119_2014_29_Fig2_HTML;40119_2014_29_Fig3_HTM...
# 111149  C2144384                                    NRR-7-2516-g005
# 111150  C0433124                    JETS-7-228-g001;JSTCR-5-35-g001
# 111151  C2082059                                    JCAS-5-155-g001
# 111152  C2748218  ATM-5-201-g046;ATM-5-201-g050;13256_2016_876_F...
# 111153  C1711212         pbio.0030147.g001;12105_2016_694_Fig6_HTML
# 111154  C0742168  can-10-673fig1;ccide-8-079Fig2;ccide-8-079Fig3...
# 111155  C0222035  ZooKeys-341-049-g003;1471-2121-5-26-2;BMRI2014...
#
# [111156 rows x 2 columns]

# %%
res = []
for index, row in data[:100].iterrows():
#     print index
    for i in row[1].split(';'):
#         print str(i)+';'+str(row[0])+';'+str(index)
        res.append(str(i)+';'+str(row[0])+';'+str(index))

# %%
final_results = pd.DataFrame(
    {
        "0":res,
    })
print final_results.head()
# Out:
#                                 0
# 0        btt-8-083Fig3;C0738276;0
# 1  abcd-28-01-0087-g03;C0738276;0
# 2        ipej030157-10;C1287716;1
# 3      aps-43-590-g001;C0576088;2
# 4      aps-43-590-g002;C0576088;2

# %%
final_results.to_csv('Final_prediction1000.csv',  index = False, header=False)

# %%
final_results
# Out:
#                                                   0
# 0                          btt-8-083Fig3;C0738276;0
# 1                    abcd-28-01-0087-g03;C0738276;0
# 2                          ipej030157-10;C1287716;1
# 3                        aps-43-590-g001;C0576088;2
# 4                        aps-43-590-g002;C0576088;2
# 5                        aps-43-590-g005;C0576088;2
# 6                        aps-43-590-g006;C0576088;2
# 7                         JCIS-2-66-g002;C0576088;2
# 8                         cios-4-77-g001;C0576088;2
# 9      CRIM.ENDOCRINOLOGY2013-190962.002;C0576088;2
# 10         CRIM.RADIOLOGY2013-235209.001;C0576088;2
# 11                          prm-20-229-1;C0576088;2
# 12              10195_2011_165_Fig1_HTML;C0576088;2
# 13              10195_2011_165_Fig2_HTML;C0576088;2
# 14                       JCAS-6-171-g001;C0576088;2
# 15                      1476-0711-4-18-2;C0576088;2
# 16                    eplasty14ic11_fig1;C0576088;2
# 17                     kjim-14-2-94-16f4;C0576088;2
# 18                  JMedLife-04-314-g001;C0576088;2
# 19                       1546-0096-5-8-4;C0576088;2
# 20                     EJHS2603-0301Fig2;C0576088;2
# 21                     EJHS2603-0301Fig4;C0576088;2
# 22                       IJN-25-317-g002;C0576088;2
# 23                        JGID-5-85-g001;C0576088;2
# 24                       JGID-6-125-g001;C0576088;2
# 25                       JGID-6-125-g002;C0576088;2
# 26                      AMHSR-4-968-g001;C0576088;2
# 27                      1477-7819-4-95-2;C0576088;2
# 28                              rju14702;C0576088;2
# 29                 poljradiol-79-51-g011;C0576088;2
# ...                                             ...
# 14184            CRIM.GM2013-850967.001;C1112160;96
# 14185         13256_2016_1043_Fig1_HTML;C1112160;96
# 14186                  jls0021026020003;C1112160;96
# 14187      CRIM.MEDICINE2013-797264.001;C1112160;96
# 14188                    gnl-6-275-g001;C1112160;96
# 14189               WIITM-10-25796-g001;C1112160;96
# 14190              kjpathol-47-606-g001;C1112160;96
# 14191                 1471-2261-9-18-21;C1112160;96
# 14192               CRIM2012-651232.003;C1112160;96
# 14193                    EUS-6-142-g004;C1112160;96
# 14194          40463_2016_119_Fig3_HTML;C0395912;97
# 14195                  IJHG-20-189-g004;C0395912;97
# 14196                   JNRP-3-189-g002;C0395912;97
# 14197                 jocmr-09-030-g002;C0395912;97
# 14198                 pone.0132890.g001;C0395912;97
# 14199                 pone.0132890.g003;C0395912;97
# 14200                 pone.0132890.g004;C0395912;97
# 14201                 pone.0132890.g006;C0395912;97
# 14202                  IJRI-22-298-g007;C0395912;97
# 14203               BMRI2015-854024.003;C0395912;97
# 14204  10-1055-s-0034-1376200-i130062-3;C0395912;97
# 14205  10-1055-s-0034-1376200-i130062-4;C0395912;97
# 14206                    LJM-1-060-g002;C0395912;97
# 14207  10-1055-s-0036-1584363-i0463or-1;C0395912;97
# 14208               WIITM-11-28049-g004;C0395912;97
# 14209              CRIOT2015-121028.003;C0395912;97
# 14210  10-1055-s-0035-1571205-i150044-1;C0395912;97
# 14211  10-1055-s-0035-1571205-i150044-2;C0395912;97
# 14212                   CTO-14-03-g-006;C0839851;98
# 14213                    ijn-10-171Fig7;C1276737;99
#
# [14214 rows x 1 columns]

# %% [raw]
# def generate_arrays_from_file(path):
#     while 1:
#         f = open(path)
#         for line in f:
#             # create numpy arrays of input data
#             # and labels, from each line in the file
#             x, y = process_line(line)
#             img = load_images(x)
#             yield (img, y)
#         f.close()
#
# model.fit_generator(generate_arrays_from_file('/my_file.txt'),
#         samples_per_epoch=10000, nb_epoch=10)

# %%
# now = pd.read_csv('/Users/sharath/Final_prediction1000.csv', delimiter=";", header=None)
# print now.head()
# k = now[[2]].values

# import sklearn.preprocessing
# label_binarizer = sklearn.preprocessing.LabelBinarizer()
# label_binarizer.fit(range(max(k)+1))
# b = label_binarizer.transform(k)
# print b[:1]


# from sklearn.preprocessing import MultiLabelBinarizer
# Y = MultiLabelBinarizer().fit_transform(k)
# print y.shape


# # temp  = pd.DataFrame(b)
# # print temp.head()

# %%
# from PIL import Image
# import numpy as np


# def generate_arrays_from_file(path):
#     for index, row in now.iterrows():
#         x = row.values[0]
#         y = b[index]
#         print "/Users/sharath/Desktop/GP/CaptionTraining2018/"+ x +".jpg"
#         img = Image.open("/Users/sharath/Desktop/GP/CaptionTraining2018/"+ x +".jpg")
#         img = img.resize((150,150), Image.ANTIALIAS)
#         x = np.expand_dims(img, axis=0)
            
    
    
    
    
    

    
    
# #     for index, row in result.iterrows():
# # #         print row.values
# #         for i,k in enumerate(row.values):
# #             print i,k
# #             if(i==0):
# #                 x = k
# #             elif(i==2):
# #                 y = k
# #         print "/Users/sharath/Desktop/GP/CaptionTraining2018/"+ x +".jpg"
# #         im = Image.open("/Users/sharath/Desktop/GP/CaptionTraining2018/"+ x +".jpg")
# #         x = np.array(im) 
# #         print x,y
# # #             yield (line, y)
        

# generate_arrays_from_file(path)
