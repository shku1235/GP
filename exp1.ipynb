# %%
import pandas as pd

# %%
data = pd.read_csv('all_concepts.csv', delimiter=":", header=None)

# %%
c1 = data[73423:73424]

# %%
c2 = data[67408:67409]

# %%
print c1
# Out:
#               0                                                  1
# 73423  C1550557  ijms-40-13-g001;NRR-8-2510-g007;gr1;jod-8-152f...

# %%
x = []
x = c1[1]

# %%
a = c1[1].values
b = c2[1].values

# %%
a = str(a).split(';')
b = str(b).split(';')

# %%
print a[:10]
print ""
print b[:10]
# Out:
# ["['ijms-40-13-g001", 'NRR-8-2510-g007', 'gr1', 'jod-8-152f4', 'IJD-56-568-g006', 'IJD-56-568-g010', 'CRIM.HEMATOLOGY2012-658745.002', 'aps-41-716-g001', 'APC-7-142-g003', 'jkms-26-824-g004']
#
# ["['ijms-40-13-g001", 'NRR-8-2510-g007', 'gr1', 'jod-8-152f4', 'IJD-56-568-g006', 'IJD-56-568-g010', 'CRIM.HEMATOLOGY2012-658745.002', 'aps-41-716-g001', 'APC-7-142-g003', 'jkms-26-824-g004']

# %%
from IPython.display import Image
name = 'gr1'
img = Image(filename="/Users/sharath/Desktop/GP/CaptionTraining2018/"+ name +".jpg")

# %%
img
